# %% [markdown]
# ## 1. Libraries

# %%
import pandas as pd
import numpy as np
import os
import string
import re
import statistics

import gensim
from gensim.models import Word2Vec
from gensim.models import Doc2Vec 
from gensim.models.doc2vec import TaggedDocument

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from collections import Counter

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer


from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression 
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
import pickle

from xgboost import XGBClassifier

# %%
pd.set_option('display.max_rows', 1000); pd.set_option('display.max_columns', 1000); pd.set_option('display.width', 1000)

# %% [markdown]
# ## 2. Functions

# %%
# Performs a series of replacements
def clean_notes(text):
    # Remove '\n'
    text = text.replace("\n", " ")
    #Remove >>>, username, date & time
    text = re.sub(r">>> ([a-z0-9_\.-]+) : \d{2}/\d{2}/\d{4} \d{2}:\d{2} ", "", text)
    #reference code ("Ref JR: " + 6 digits)
    text = re.sub("Ref JR: \d{6} ", "", text)
    return text

# %%
# Remove punctuation
def remove_punctuation(text):
    translator = str.maketrans(string.punctuation, ' '*len(string.punctuation)) 
    text = text.translate(translator)
    text = re.sub(r'\s+'," ", text)
    return text

# %%
# Define Stopwords
nltk.download('stopwords')
stopwords = stopwords.words("english")

wo_stop_words = ['location', 'loc', 'description', 'fault', 'action', 'work', 'start', 'end']

for i in wo_stop_words:
    if i not in stopwords:
        stopwords.append(i)
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
# remove stopwords, lemmatize, returns only alphabet characters

nltk.download('punkt') # Tokenizer model
nltk.download('wordnet') # Lexical database
# nltk.download('punkt_tab')

def remove_stopwords_lemmatize(sentence):
    # Tokenize
    tokens = word_tokenize(sentence)
    tokens = [word.lower() for word in tokens]

    # Remove stopwords
    tokens = [word for word in tokens if word not in stopwords]
    
    # Lemmatize
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    
    # Only contains alphabet characters
    tokens = " ".join([word for word in tokens if word.isalpha()])

    return tokens
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
# Filter out the noise from a text by removing words that appear less than 3
def filter_noise(text):
    text = ' '.join([word for word in word_tokenize(text) if word_counts[word] > 3])
    return text

# %%
# Transforms text into numerical vectors using Word2Vec model
class MeanEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        self.dim = len(next(iter(word2vec.values())))
    def fit(self, X, y): 
            return self
    def transform(self, X):
            return np.array([np.mean([self.word2vec[w] for w in words if w in self.word2vec] or [np.zeros(self.dim)], axis=0) for words in X])

# %%
# Tokenizes the text of each document for Doc2Vec model
def tokenize_text(text):
    tokens = []
    for word in nltk.word_tokenize(text):
        tokens.append(word)
    return tokens

# %%
# Generating labels and features for Doc2Vec model
def vec_for_learning(model, tagged_docs):
    sents = tagged_docs.values
    targets, regressors = zip(*[(doc.tags[0], model.infer_vector(doc.words)) for doc in sents])
    return targets, regressors

# %%
# ML model except XGBoost
def train_model(model, vectorizer, X_train, y_train, X_test, y_test, param_grid):
    # Fit model
    grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    # Get the best model from grid search
    best_model = grid_search.best_estimator_
    # Generate predictions
    y_pred = best_model.predict(X_test)
    # Accuracy Score
    score = round((accuracy_score(y_test, y_pred)*100),2)
    
    print(f'Vectorizer = {vectorizer}, Accuracy = {score}%')

# %%
# XGBoost model
def xgb_train_model(xg, vectorizer, X_train, y_train, X_test, y_test, param_grid):
     # Fit model
     le = LabelEncoder()
     y_xgb = le.fit_transform(y_train)
     grid_search = GridSearchCV(xg, param_grid, cv=5, n_jobs=-1)
     grid_search.fit(X_train, y_xgb)
     # Get the best model from grid search
     best_model = grid_search.best_estimator_
     # Generate predictions
     y_pred = best_model.predict(X_test)
     y_pred = le.inverse_transform(y_pred)
    # Accuracy Score
     score = round((accuracy_score(y_test, y_pred)*100),2)
    
     print(f'Vectorizer = {vectorizer}, Accuracy = {score}%')

# %% [markdown]
# ## 3. Datasets and Preprocessing

# %% [markdown]
# ### a. Training Dataset

# %% [markdown]
# Training Data: Jan 2020 to Jun 2023

# %%
# Load training datasets
tmp_data_1 = pd.read_csv("0_NEL_MMS_WO (2020-2022)_withnotes.csv")
tmp_data_2 = pd.read_csv("0_NEL_MMS_WO (Jan2023 - Jul2023).csv")

# %%
# Ensure both dataset has the same columns
tmp_data_2 = tmp_data_2[tmp_data_1.columns]
# Merge dataset
tmp_data = pd.concat([tmp_data_1, tmp_data_2])

# %%
# Filter CM Job
train_df = tmp_data[tmp_data["JOB_TYPE"] == "CM"].copy(deep = True)
print(f'CM Work Order DataFrame: {train_df.shape[0]} rows')

# Extract notes & symptom, drop those that are na
train_df = train_df[["NOTES", "DESCRIPTION_SYMPTOM"]]
train_df = train_df.dropna(how="any")

# Rest axis & rename columns
train_df = train_df.reset_index(drop=True)
train_df = train_df.rename(columns = {'DESCRIPTION_SYMPTOM': 'TARGET'})
print(f'Symptom Work Order DataFrame: {train_df.shape[0]} rows')
# Out:
# CM Work Order DataFrame: 66838 rows
# Symptom Work Order DataFrame: 27189 rows

# %%
train_df.head()
# Out:
#                                                NOTES                                             TARGET
# 0  >>> nepsas26 : 25/01/2020 08:57\nFault: Intrus...  Patron sensor alignment out/Patron Sensor bloc...
# 1  >>> nesctc02 : 30/01/2020 09:57\nFault: No com...                                           No Comms
# 2  >>> nealms01 : 29/01/2020 07:21\nFault : CSC R...                           CSC R/W/C-Through Reader
# 3  >>> nealsn01 : 04/01/2020 10:53\nFault : BNA  ...      Other Hardware faults/Other hardware problems
# 4  >>> nepsas26 : 06/01/2020 14:00\nFault: NBX un...                          Magazine 1/Change Notebox

# %% [markdown]
# ### b. Testing Dataset

# %% [markdown]
# Testing Data: Jul 2023 - Dec 2023

# %%
# Load testing dataset, ensure both dataset has the same columns as training datasets
tmp_data_3 = pd.read_csv('0_NEL_MMS_WO (Jul2023 - Dec2023).csv')
tmp_data_3 = tmp_data_3[tmp_data.columns]

# %%
# Filter CM Job
test_df = tmp_data_3[tmp_data_3["JOB_TYPE"] == "CM"].copy(deep = True)
print(f'CM Work Order DataFrame: {test_df.shape[0]} rows')

# Extract notes & symptom, drop those that are N.A.
test_df = test_df[["NOTES", "DESCRIPTION_SYMPTOM"]]
test_df = test_df.dropna(how="any")

# Rest axis & Rename columns
test_df = test_df.reset_index(drop=True)
test_df = test_df.rename(columns = {'DESCRIPTION_SYMPTOM': 'TARGET'})
print(f'Symptom Work Order DataFrame: {test_df.shape[0]} rows')
# Out:
# CM Work Order DataFrame: 8985 rows
# Symptom Work Order DataFrame: 5407 rows

# %%
test_df.head()
# Out:
#                                                NOTES                                             TARGET
# 0  >>> nealsn01 : 26/07/2022 09:05\nFault : Gate ...                                               Hang
# 1  >>> nepsas26 : 28/07/2022 10:36\nFault: Gate s...                                    ECU Replacement
# 2  >>> nepsas26 : 28/07/2022 11:07\nFault: Gate s...                                    ECU Replacement
# 3  >>> dtacto01 : 19/07/2022 08:49\nFault : Intru...  Patron sensor alignment out/Patron Sensor bloc...
# 4  >>> dtsgto04 : 06/07/2022 13:11\nFault : Patro...         Patron Sensor Alignment Out/Gate Intrusion

# %% [markdown]
# ## 4. NLP

# %% [markdown]
# ### a. Training Dataset

# %%
# Apply fucntion
train_df['NOTES'] = train_df['NOTES'].apply(clean_notes)
train_df['NOTES_PROCESSED'] = train_df['NOTES'].apply(remove_punctuation)
train_df['NOTES_PROCESSED'] = train_df['NOTES_PROCESSED'].apply(remove_stopwords_lemmatize)

# %%
# Counts the frequency of each word
notes_tok = [word_tokenize(word) for word in train_df['NOTES_PROCESSED']]

word_vocab = []
for line in notes_tok:
    for word in line:
        word_vocab.append(word)

word_counts = Counter(word_vocab)
word_counts
# Out:
# Counter({'intrusion': 414,
#          'alarm': 5953,
#          'corrective': 4189,
#          'site': 5748,
#          'service': 8143,
#          'checked': 7538,
#          'found': 10706,
#          'sensor': 2294,
#          'intermittent': 351,
#          'adjusted': 791,
#          'position': 1056,
#          'performed': 2876,
#          'patron': 155,
#          'management': 76,
#          'test': 9552,
#          'ok': 16587,
#          'tested': 5914,
#          'put': 4568,
#          'gate': 3723,
#          'back': 8536,
#          'comm': 1121,
#          'machine': 2111,
#          'degraded': 380,
#          'mode': 1635,
#          'unplug': 397,
#          'plug': 454,
#          'lan': 352,
#          'cable': 1303,
#          'check': 11031,
#          'status': 9429,
#          'shown': 736,
#          'csc': 125,
#          'rw': 47,
#          'error': 3461,
#          'afc': 1113,
#          'remote': 1649,
#          'reader': 158,
#          'secured': 494,
#          'connection': 833,
#          'reboot': 1479,
#          'initalized': 338,
#          'hardware': 741,
#          'bna': 1819,
#          'cover': 774,
#          'close': 1299,
#          'ttk': 1208,
#          'top': 900,
#          'black': 47,
#          'drop': 241,
#          'causing': 139,
#          'closed': 1429,
#          'aligned': 705,
#          'gtm': 739,
#          'nbx': 272,
#          'unable': 3260,
#          'initialise': 116,
#          'note': 1829,
#          'jam': 520,
#          'cleaned': 746,
#          'sm': 449,
#          'changed': 196,
#          'notebox': 187,
#          'able': 2211,
#          'intermtent': 1,
#          'accept': 41,
#          'cleanup': 282,
#          'path': 179,
#          'frequent': 63,
#          'jammed': 892,
#          'latch': 61,
#          'broken': 536,
#          'proceed': 989,
#          'net': 1077,
#          'response': 258,
#          'slow': 338,
#          'monitor': 3319,
#          'pax': 1209,
#          'feedback': 1372,
#          'insert': 151,
#          'coin': 633,
#          'slot': 256,
#          'misaligned': 19,
#          'insertion': 79,
#          'unit': 2869,
#          'detect': 194,
#          'id': 428,
#          'toggled': 39,
#          'gear': 103,
#          'initialised': 456,
#          'activated': 1050,
#          'login': 147,
#          'deactivated': 6,
#          'power': 3137,
#          'old': 2396,
#          'value': 242,
#          'change': 1051,
#          'another': 200,
#          'open': 2109,
#          'degrade': 58,
#          'inside': 371,
#          'verifier': 131,
#          'removed': 804,
#          'handover': 154,
#          'station': 3231,
#          'staff': 4830,
#          'monitored': 1197,
#          'usage': 111,
#          'keypad': 188,
#          'connector': 704,
#          'terminal': 716,
#          'setup': 52,
#          'successfully': 1028,
#          'system': 1817,
#          'returned': 53,
#          'acceptor': 65,
#          'oos': 900,
#          'x': 306,
#          'cent': 72,
#          'passed': 154,
#          'stn': 2692,
#          'total': 20,
#          'ticket': 892,
#          'feeding': 32,
#          'full': 221,
#          'revenue': 78,
#          'dispenser': 308,
#          'clean': 1027,
#          'roller': 588,
#          'reiected': 1,
#          'pc': 1133,
#          'still': 1298,
#          'persists': 248,
#          'suspect': 207,
#          'faulty': 2305,
#          'follow': 2536,
#          'high': 247,
#          'rejection': 2,
#          'stuck': 1077,
#          'shut': 94,
#          'return': 806,
#          'deivce': 1,
#          'asm': 273,
#          'credit': 50,
#          'box': 719,
#          'feed': 46,
#          'reject': 11,
#          'bin': 27,
#          'issue': 783,
#          'void': 7,
#          'successful': 492,
#          'maintenance': 618,
#          'panel': 1264,
#          'blank': 1076,
#          'screen': 672,
#          'hangged': 2,
#          'informed': 1183,
#          'log': 4806,
#          'managed': 84,
#          'clear': 1121,
#          'lock': 2616,
#          'module': 286,
#          'dio': 5,
#          'door': 10312,
#          'swicth': 3,
#          'piece': 166,
#          'one': 1224,
#          'restart': 1117,
#          'verifeir': 1,
#          'ccu': 161,
#          'key': 298,
#          'remove': 392,
#          'recovered': 211,
#          'swing': 403,
#          'bit': 38,
#          'loose': 507,
#          'default': 905,
#          'home': 39,
#          'tighten': 278,
#          'screw': 577,
#          'logout': 26,
#          'cash': 69,
#          'measure': 625,
#          'adaptor': 66,
#          'dc': 317,
#          'resecure': 29,
#          'replaced': 8371,
#          'issued': 231,
#          'earlier': 73,
#          'access': 268,
#          'opened': 212,
#          'foudn': 12,
#          'switch': 2796,
#          'came': 108,
#          'dropped': 45,
#          'drum': 33,
#          'initialsed': 1,
#          'paper': 345,
#          'read': 93,
#          'card': 2400,
#          'option': 104,
#          'greyoff': 52,
#          'external': 203,
#          'added': 48,
#          'hand': 433,
#          'normal': 10150,
#          'cleaning': 193,
#          'monitoring': 776,
#          'vna': 4,
#          'wheb': 2,
#          'cancel': 40,
#          'reason': 8,
#          'entered': 9,
#          'booted': 2,
#          'device': 369,
#          'detected': 268,
#          'initialized': 43,
#          'hard': 354,
#          'shutdown': 790,
#          'sc': 2996,
#          'comms': 1018,
#          'barrier': 1016,
#          'control': 1221,
#          'local': 936,
#          'flap': 2413,
#          'rubbing': 383,
#          'cabinet': 387,
#          'failed': 1216,
#          'printer': 605,
#          'print': 297,
#          'receipt': 235,
#          'cleared': 3743,
#          'residue': 17,
#          'blocked': 230,
#          'affected': 338,
#          'bracket': 271,
#          'exact': 65,
#          'fare': 64,
#          'show': 4750,
#          'roll': 22,
#          'pid': 701,
#          'normalised': 1500,
#          'buying': 45,
#          'stt': 5,
#          'grey': 83,
#          'working': 1145,
#          'atm': 26,
#          'port': 209,
#          'set': 622,
#          'setting': 146,
#          'inserted': 96,
#          'initialize': 17,
#          'touch': 487,
#          'hit': 57,
#          'passenger': 655,
#          'diagnostic': 107,
#          'tap': 477,
#          'display': 3028,
#          'side': 2347,
#          'swapped': 487,
#          'vga': 87,
#          'problem': 206,
#          'persist': 1016,
#          'entry': 222,
#          'mismatch': 35,
#          'og': 6,
#          'sam': 33,
#          'conducted': 239,
#          'functional': 844,
#          'hole': 42,
#          'silver': 1,
#          'rejected': 20,
#          'standard': 12,
#          'resecured': 23,
#          'tightened': 230,
#          'hang': 1264,
#          'reset': 4256,
#          'touchscreen': 21,
#          'also': 683,
#          'calibration': 28,
#          'holder': 55,
#          'hold': 84,
#          'thin': 3,
#          'wire': 398,
#          'spring': 91,
#          'fixed': 243,
#          'functioning': 144,
#          'mechanism': 71,
#          'slightly': 68,
#          'slanted': 15,
#          'servive': 2,
#          'long': 48,
#          'disable': 43,
#          'permanent': 170,
#          'upgrade': 19,
#          'tie': 34,
#          'awaiting': 78,
#          'replacement': 1451,
#          'lswing': 1,
#          'code': 928,
#          'e': 372,
#          'tag': 38,
#          'buy': 56,
#          'init': 36,
#          'money': 28,
#          'number': 875,
#          'advised': 70,
#          'repl': 2,
#          'ace': 386,
#          'new': 4009,
#          'due': 3460,
#          'tally': 21,
#          'std': 12,
#          'biox': 1,
#          'printout': 22,
#          'shwos': 2,
#          'physically': 473,
#          'empty': 27,
#          'requested': 443,
#          'replenish': 15,
#          'belting': 19,
#          'count': 27,
#          'manual': 173,
#          'logon': 31,
#          'using': 389,
#          'initalize': 18,
#          'need': 700,
#          'initilaise': 4,
#          'slowly': 25,
#          'condition': 600,
#          'cant': 24,
#          'keyin': 3,
#          'pin': 270,
#          'voltage': 473,
#          'reload': 268,
#          'always': 47,
#          'used': 50,
#          'space': 24,
#          'memory': 33,
#          'boot': 98,
#          'resume': 110,
#          'operation': 1573,
#          'remark': 27,
#          'double': 53,
#          'sys': 248,
#          'intermittenly': 22,
#          'align': 381,
#          'plc': 379,
#          'psm': 267,
#          'use': 193,
#          'pdu': 25,
#          'flickering': 278,
#          'sitei': 1,
#          'write': 16,
#          'ctk': 540,
#          'battery': 1031,
#          'reinitialise': 2,
#          'pad': 22,
#          'responding': 25,
#          'purchased': 38,
#          'lower': 688,
#          'motor': 1191,
#          'lever': 52,
#          'inform': 139,
#          'cso': 1975,
#          'cbx': 74,
#          'tapping': 15,
#          'ddjusted': 1,
#          'replace': 3360,
#          'supply': 778,
#          'initiailised': 1,
#          'together': 51,
#          'coinbox': 33,
#          'alignment': 334,
#          'synchronise': 6,
#          'verified': 865,
#          'onsite': 2968,
#          'vault': 24,
#          'serured': 1,
#          'limit': 221,
#          'mcw': 34,
#          'unlock': 107,
#          'information': 48,
#          'escrow': 23,
#          'occ': 1876,
#          'get': 101,
#          'collect': 454,
#          'placed': 37,
#          'handle': 64,
#          'backend': 44,
#          'assist': 45,
#          'centre': 31,
#          'bnk': 474,
#          'mohd': 9,
#          'yazid': 5,
#          'yunus': 4,
#          'tenant': 37,
#          'shop': 138,
#          'elevn': 2,
#          'complained': 15,
#          'aircon': 1277,
#          'fcu': 311,
#          'running': 1394,
#          'frp': 517,
#          'alan': 3,
#          'koh': 6,
#          'chian': 1,
#          'huat': 1,
#          'attend': 686,
#          'time': 10056,
#          'psd': 1295,
#          'temperature': 581,
#          'actual': 152,
#          'person': 15,
#          'sathishkumar': 2,
#          'hgn': 473,
#          'abdul': 12,
#          'azim': 1,
#          'room': 1080,
#          'ceiling': 138,
#          'water': 621,
#          'leaking': 411,
#          'condensation': 270,
#          'pgl': 1026,
#          'jeremy': 1,
#          'choo': 5,
#          'jian': 1,
#          'xiang': 1,
#          'cheer': 34,
#          'near': 368,
#          'exit': 242,
#          'c': 2130,
#          'report': 2044,
#          'seepage': 23,
#          'tan': 44,
#          'chon': 2,
#          'teck': 3,
#          'store': 64,
#          'peu': 261,
#          'ser': 521,
#          'sharon': 2,
#          'outside': 50,
#          'psc': 413,
#          'grille': 56,
#          'condenstion': 1,
#          'poh': 1,
#          'platform': 1206,
#          'humid': 5,
#          'chiller': 147,
#          'summary': 594,
#          'bgk': 606,
#          'daniel': 4,
#          'soh': 3,
#          'transcomm': 3,
#          'reported': 4410,
#          'trancomms': 2,
#          'warm': 128,
#          'properly': 170,
#          'cnt': 710,
#          'azhiem': 1,
#          'syed': 2,
#          'ismail': 1,
#          'loud': 212,
#          'noise': 429,
#          'cooling': 773,
#          'tower': 51,
#          'wcc': 39,
#          'bearing': 244,
#          'noisy': 205,
#          'padlock': 6,
#          'rectification': 335,
#          'clt': 14,
#          'trip': 1143,
#          'run': 1568,
#          'kvn': 502,
#          'koon': 3,
#          'chye': 1,
#          'concourse': 382,
#          'er': 13,
#          'lti': 578,
#          'dharmalingam': 1,
#          'mulkaikodi': 1,
#          'pcu': 106,
#          'compressor': 916,
#          'bypass': 58,
#          'vacuum': 126,
#          'filter': 478,
#          'core': 15,
#          'betrand': 2,
#          'goh': 103,
#          'soo': 2,
#          'kheng': 2,
#          'sayou': 1,
#          'lazim': 1,
#          'rahim': 81,
#          'ptp': 587,
#          'gan': 2,
#          'soon': 105,
#          'kim': 3,
#          'antony': 2,
#          'cold': 156,
#          'please': 1090,
#          'help': 274,
#          'degc': 112,
#          'skg': 623,
#          'ng': 4,
#          'yew': 1,
#          'chuan': 1,
#          'cehck': 14,
#          'khairul': 4,
#          'ariffin': 1,
#          'air': 2444,
#          'con': 453,
#          'lee': 70,
#          'breakdown': 112,
#          'ben': 4,
#          'ngai': 1,
#          'kan': 1,
#          'sulaiman': 4,
#          'office': 97,
#          'leak': 481,
#          'wlh': 481,
#          'wong': 11,
#          'kai': 2,
#          'cheong': 3,
#          'lift': 2285,
#          'hot': 204,
#          'degree': 77,
#          'programmed': 23,
#          'erms': 74,
#          'computer': 298,
#          'iscs': 1125,
#          'escalator': 2585,
#          'normaloperation': 2,
#          'gws': 1758,
#          'blue': 311,
#          'signal': 557,
#          'bak': 3,
#          'comb': 912,
#          'landing': 1176,
#          'elderly': 114,
#          'male': 120,
#          'leaning': 4,
#          'lost': 577,
#          'balance': 360,
#          'miss': 26,
#          'step': 318,
#          'woman': 7,
#          'age': 9,
#          'refused': 37,
#          'go': 165,
#          'hospital': 199,
#          'given': 56,
#          'first': 113,
#          'aid': 21,
#          'safety': 2548,
#          'handrail': 1362,
#          'permitted': 63,
#          'infra': 300,
#          'yellow': 187,
#          'demarcation': 96,
#          'rh': 358,
#          'female': 111,
#          'fell': 440,
#          'downm': 1,
#          'riding': 180,
#          'carrying': 41,
#          'trolley': 38,
#          'mpsd': 157,
#          'braking': 139,
#          'distance': 39,
#          'relay': 1115,
#          'drunk': 27,
#          'away': 26,
#          'opeartion': 3,
#          'nromal': 1,
#          'incoming': 103,
#          'department': 100,
#          'technician': 19,
#          'dual': 13,
#          'speed': 528,
#          'modification': 23,
#          'defect': 138,
#          'huge': 4,
#          'luggage': 8,
#          'carry': 156,
#          'thing': 20,
#          'aged': 15,
#          'intend': 1,
#          'onto': 25,
#          'upper': 566,
#          'sustained': 4,
#          'head': 139,
#          'injury': 43,
#          'conveyed': 5,
#          'sgh': 25,
#          'floor': 182,
#          'plate': 741,
#          'injured': 9,
#          'sent': 410,
#          'stopped': 224,
#          'public': 84,
#          'stop': 946,
#          'button': 389,
#          'function': 3520,
#          'bca': 296,
#          'approved': 73,
#          'oepration': 9,
#          'switchalignment': 1,
#          'auxiliary': 164,
#          'brake': 1238,
#          'light': 1146,
#          'lady': 29,
#          'loss': 430,
#          'almost': 14,
#          'tension': 268,
#          'abnormal': 248,
#          'sound': 540,
#          'resumed': 216,
#          'dbg': 471,
#          'young': 10,
#          'boy': 12,
#          'playing': 69,
#          'protruding': 4,
#          'stair': 7,
#          'case': 71,
#          'railing': 2,
#          'tripped': 1027,
#          'switchand': 1,
#          'arrival': 1179,
#          'tachnometer': 1,
#          'oil': 394,
#          'skirt': 104,
#          'lh': 333,
#          'confirmed': 252,
#          'main': 538,
#          'recommended': 8,
#          'followed': 90,
#          'turned': 38,
#          'igd': 157,
#          'rje': 1,
#          'flood': 35,
#          'spoil': 277,
#          'esc': 2792,
#          'permission': 245,
#          'cloth': 72,
#          'remvoed': 1,
#          'spoiled': 19,
#          'right': 342,
#          'chain': 106,
#          'contact': 579,
#          'middle': 68,
#          'pressed': 41,
#          'unknown': 860,
#          'escaltor': 6,
#          'year': 34,
#          'tt': 28,
#          'people': 17,
#          'man': 203,
#          'tolost': 1,
#          'sweater': 1,
#          'lowe': 5,
#          'cause': 180,
#          'stand': 13,
#          'damaged': 74,
#          'part': 136,
#          'pending': 2205,
#          'joint': 92,
#          'inspection': 87,
#          'ahead': 2,
#          'oms': 8,
#          'inspected': 173,
#          'jan': 16,
#          'missing': 374,
#          'bad': 92,
#          'serviced': 38,
#          'student': 11,
#          'shoe': 102,
#          'lace': 12,
#          'buzzer': 53,
#          'closing': 349,
#          'street': 132,
#          'level': 793,
#          'event': 927,
#          'dcp': 43,
#          'sill': 77,
#          'ground': 98,
#          'malfunction': 27,
#          'ux': 37,
#          'auxillary': 11,
#          'clip': 21,
#          'secure': 211,
#          'order': 213,
#          'elrv': 8,
#          'buzzering': 1,
#          'gf': 2,
#          'checking': 513,
#          'bar': 370,
#          'pressure': 958,
#          'lrv': 142,
#          'valve': 615,
#          'fail': 1630,
#          'intermittently': 219,
#          'adjust': 454,
#          'mechanical': 19,
#          'led': 2658,
#          'complain': 105,
#          'indicator': 160,
#          'board': 659,
#          'sbst': 46,
#          'spoilt': 56,
#          'complaint': 209,
#          'job': 3570,
#          'refer': 1544,
#          'indicate': 160,
#          'controller': 1551,
#          'wiring': 328,
#          'showing': 700,
#          'notify': 3,
#          'automatically': 35,
#          'em': 1082,
#          'breaker': 243,
#          'toggling': 768,
#          'n': 3004,
#          'strong': 28,
#          'hydraulic': 38,
#          'smell': 115,
#          'lot': 38,
#          'shaft': 40,
#          'pit': 97,
#          'plunger': 40,
#          'additional': 44,
#          'freshener': 24,
#          'blower': 36,
#          'fan': 1060,
#          'pcb': 82,
#          'program': 23,
#          'tunning': 2,
#          'without': 121,
#          'resulting': 9,
#          'worried': 1,
#          'child': 8,
#          'appreciate': 2,
#          'rectify': 629,
#          'urgently': 4,
#          'car': 15432,
#          'upon': 1080,
#          'single': 21,
#          'phase': 134,
#          'building': 194,
#          'call': 569,
#          'flourscent': 6,
#          'tube': 113,
#          'starter': 60,
#          'dim': 37,
#          'ebops': 10,
#          'ballast': 8,
#          'equipment': 823,
#          'contractor': 113,
#          'keep': 179,
#          'opening': 267,
#          'fully': 166,
#          'retractable': 8,
#          'detached': 9,
#          'knot': 1,
#          'moving': 125,
#          'showed': 142,
#          'communication': 758,
#          'find': 105,
#          'protection': 23,
#          'got': 149,
#          'object': 174,
#          'continuous': 22,
#          'ringing': 22,
#          'nobody': 5,
#          'tci': 2061,
#          'jerking': 65,
#          'suddenly': 21,
#          'went': 303,
#          'urgent': 37,
#          'pump': 604,
#          'short': 256,
#          'circuit': 859,
#          'mso': 161,
#          'cooler': 42,
#          'fireman': 50,
#          'non': 184,
#          'area': 381,
#          'calibrate': 13,
#          'operator': 177,
#          'stucked': 82,
#          'currently': 132,
#          'suspected': 278,
#          'period': 19,
#          'ensure': 35,
#          'fuse': 168,
#          'l': 1348,
#          'repair': 117,
#          'sometimes': 19,
#          'delayed': 21,
#          'hear': 163,
#          'likely': 11,
#          'worn': 974,
#          'component': 37,
#          'cam': 339,
#          'take': 168,
#          'many': 37,
#          'happen': 38,
#          'intercom': 285,
#          'talking': 11,
#          'recurring': 78,
#          'ddp': 29,
#          'fr': 91,
#          'soft': 152,
#          'tomorrow': 53,
#          'morning': 131,
#          'technical': 39,
#          'support': 151,
#          'engineer': 305,
#          'configure': 79,
#          'hr': 501,
#          'today': 25,
#          'asked': 28,
#          'otis': 37,
#          'philip': 1,
#          'tight': 33,
#          'okay': 217,
#          'already': 351,
#          'fluo': 1,
#          'blown': 98,
#          'dw': 26,
#          'input': 235,
#          'accumulated': 7,
#          'logged': 18,
#          'thanks': 5,
#          'fire': 505,
#          'somebody': 3,
#          'attendant': 11,
#          'turn': 233,
#          'shaking': 11,
#          'several': 41,
#          'attempt': 101,
#          'completely': 17,
#          'testing': 544,
#          'screeching': 24,
#          'soudn': 1,
#          'halfway': 33,
#          'twice': 80,
#          'edge': 20,
#          'hanged': 239,
#          'deg': 45,
#          'runnng': 2,
#          'ack': 478,
#          'blow': 25,
#          'blink': 12,
#          'bulb': 109,
#          'adjustment': 337,
#          'carried': 368,
#          'w': 256,
#          'tabulated': 2,
#          'table': 61,
#          'mw': 10,
#          'cw': 45,
#          'abnormality': 1395,
#          'pfr': 266,
#          'turnbuckle': 11,
#          'date': 7487,
#          'north': 78,
#          'bound': 291,
#          'south': 64,
#          'wrong': 224,
#          'train': 11168,
#          'timing': 741,
#          'skgn': 290,
#          'pti': 288,
#          'leading': 2279,
#          'tc': 1046,
#          'schedule': 252,
#          'rtu': 403,
#          'link': 1025,
#          'peer': 31,
#          'finding': 1366,
#          'schematic': 172,
#          'hisevent': 311,
#          'process': 93,
#          'nelrtuapp': 1,
#          'file': 75,
#          'size': 32,
#          'large': 7,
#          'rebooted': 58,
#          'cqy': 405,
#          'ssh': 3,
#          'ping': 206,
#          'shah': 6,
#          'well': 94,
#          'getting': 9,
#          'approval': 63,
#          'cc': 183,
#          'standby': 219,
#          'leaving': 19,
#          'hbf': 1015,
#          'fualt': 4,
#          'approaching': 50,
#          'unble': 12,
#          'cab': 2173,
#          'nb': 1355,
#          'captured': 497,
#          'punct': 32,
#          'tdms': 177,
#          'pe': 5,
#          'departure': 46,
#          'resutl': 1,
#          'needed': 109,
#          'opr': 8,
#          'recovery': 128,
#          'yes': 27,
#          'failure': 3370,
#          'manually': 197,
#          'pgln': 434,
#          'track': 1142,
#          'pd': 716,
#          'radio': 596,
#          'self': 1138,
#          'session': 40,
#          'creating': 5,
#          'view': 519,
#          'trainborne': 472,
#          'cctv': 1364,
#          'play': 235,
#          'pa': 2061,
#          'gtpa': 59,
#          'coc': 262,
#          'terrence': 10,
#          'toolbar': 8,
#          'menu': 13,
#          'free': 193,
#          'uanble': 4,
#          'next': 257,
#          'viewing': 125,
#          'tried': 252,
#          'demonstrated': 1,
#          'selecting': 6,
#          'mainline': 791,
#          'clicking': 3,
#          'icon': 61,
#          'nothing': 73,
#          'happens': 10,
#          'noticed': 86,
#          'pressing': 13,
#          'massage': 4,
#          'seen': 235,
#          'contacted': 5,
#          'coms': 39,
#          'investigation': 2043,
#          'particular': 403,
#          'num': 5,
#          'might': 17,
#          'caused': 99,
#          'unblocked': 1,
#          'normalized': 774,
#          'mentioned': 183,
#          'stayed': 1,
#          'buffer': 99,
#          'steph': 1,
#          'method': 2,
#          'solving': 1,
#          'apply': 101,
#          'send': 496,
#          'observed': 207,
#          'ret': 111,
#          'cond': 156,
#          'initialization': 17,
#          'fb': 107,
#          'interfere': 14,
#          'sig': 1032,
#          'carnum': 2,
#          'trainnum': 2,
#          'schednum': 2,
#          'destnum': 2,
#          'crewnum': 2,
#          'referred': 214,
#          'manpower': 190,
#          'nkh': 174,
#          'cd': 80,
#          'ejecter': 53,
#          'sump': 58,
#          'flow': 158,
#          'dismantle': 81,
#          'type': 93,
#          'iwpc': 22,
#          'bm': 41,
#          'later': 63,
#          'come': 96,
#          'tank': 58,
#          'calling': 6,
#          'manitor': 1,
#          'coming': 76,
#          'float': 59,
#          'intermitted': 2,
#          'rectified': 108,
#          'discharge': 59,
#          ...})

# %%
# Filter words that appear less than 3
train_df['NOTES_PROCESSED'] = train_df['NOTES_PROCESSED'].apply(filter_noise)

# Remove any that contain only 1 word or are empty 
train_df['LENGTH'] = train_df['NOTES_PROCESSED'].apply(lambda x: len(x.split()))
train_df = train_df[train_df['LENGTH']>1]
train_df = train_df.reset_index(drop=True)
train_df = train_df.drop('LENGTH', axis=1)

# Reshuttle cols
train_df=train_df[['NOTES','NOTES_PROCESSED','TARGET']]

# %%
# Convert to lower case, find unique categories
train_df['TARGET'] = train_df['TARGET'].apply(lambda x: x.lower())
sorted(train_df['TARGET'].unique())
# Out:
# [' i/o gp a card failure',
#  '(cnt/lti) lift intercom voice communication not working',
#  '(do not use) led display com link error',
#  '(do not use) led display unable to show priority message',
#  '(do not use) pas pmf 906a analogue monitor card fault alarm',
#  '(do not use) pas pnc 903a aes/ebu output module fault alarm',
#  '(do not use) unknown symptom',
#  '1 plc down',
#  '12" monitor',
#  '18 " monitor/lcd monitor replacement',
#  '22" lcd monitor replacement ',
#  '24vdc absence',
#  'abnormal sound generated from equipment',
#  'abnormal wear',
#  'adjustment of the swing gate ',
#  'air flow not  strong',
#  'air leaking',
#  'air pressure too strong',
#  'air-con cover/ducting/grille dis-lodged ( mis-aligned )',
#  'alarm / event message not update / not received',
#  'alarm led blinking',
#  'alarm ups battery/alarm module/alarm battery',
#  'alarm ups module/replacement of alarm battery',
#  'alarms / event acknowledge problem -- cannot acknowledge / auto acknowledge',
#  'alarms / event messages sent to wrong gws profile',
#  'alarms at gws',
#  'all mode lost',
#  'all other faults not listed',
#  'all/ multiple doorways failed',
#  'animated symbol keep flashing even it has been acknowledged',
#  'animated symbol status on gws is not tally with the physical equipment status ',
#  'animation discrepancy',
#  'animation objects on gws schematics show unknown status ',
#  'animation problem(gws)',
#  'animation-cbi eg,cbi monitor table invalid/esb,esp,spks activation/cbi detector/',
#  'animation-dms, eg,blue screen',
#  'animation-psd',
#  'animation-track circuit',
#  'ap on track circuit/screen',
#  'application software not responding',
#  'ascv to atc link failure',
#  'atc net related fault',
#  'atc wbs_line/lru failure',
#  'ato failed',
#  'ato/atp  and com failed',
#  'ato/atp failed',
#  'atp failed',
#  'ats environment stop / crashed (one environment down)',
#  'ats server 1 & server 2 database data not synchronized',
#  'auto gate unable to operate',
#  'auto rebooting',
#  'auto test failed',
#  'auto wake up failed',
#  'availability fault',
#  'back box/ base broken',
#  'barrier alignment/rubbing/flap jammed',
#  'beacon missed',
#  'ber measurement out off range',
#  'bgk',
#  'bi-parting glass shattered',
#  'blank',
#  'blank / wrong / partial information displayed on pid/ld',
#  'blank screen',
#  'blue screen',
#  'bms ddc offline',
#  'bms workstation show error message when starting up',
#  'bms workstation shows wrong equipment status  ',
#  'bms ws unable to control the equipment ',
#  'bna disable/coins & nets only',
#  'bna disable/coins and nets only',
#  'bna issues/ note box issues',
#  'bna not working',
#  'bna note jammed/unable recognise the note',
#  'bna replacement',
#  'bna/notes jammed in bna/notebox problem/ high rejection of dollar note/key jammed at notebox',
#  'brake not release',
#  'breakglass glass broken',
#  'breakglass unit damaged',
#  'breakglass unit out of position',
#  'buco discrepancy/notebox showed old value',
#  'bulb dimmed',
#  'burning smell',
#  'burnt marked',
#  'buzzer no sound',
#  'cabinet base plate broken',
#  'cabinet door cannot open/close',
#  'cable open/short circuit',
#  'cables loosen/intermitent or bad connectivity',
#  'cables loosen/intermittent or bad connectivity',
#  'call drop',
#  'caller id keep on displaying on gws caller banner',
#  'camera image blur/foggy/dirty',
#  'camera image flickering',
#  'camera image freeze',
#  'camera no video',
#  'camera wrong coverage',
#  'can not issue ticket/cannot issued paper ticket',
#  'cannot login to coswin/windows',
#  'car light flickering',
#  'card is faulty ',
#  'cash box faulty/limit switch adjustment',
#  'cash box issues',
#  'cash only',
#  'cash only/nets error count/wrong terminal id',
#  'cau breakdown',
#  'cau enclosure damaged',
#  'cbn major / minor alarm',
#  'cctv error message',
#  'cctv image not updated or incorrect.',
#  'cctv image view / image selection / recording fail with / without error message',
#  'cctv viewing to train failure',
#  'cf card replacement',
#  'change of end failure',
#  'channel a down (no relevant codes)',
#  'channel b down (no relevant codes)',
#  'channel c down (no relevant codes)',
#  'charger failure alarm',
#  'claimed unit cannot changed setting.',
#  'claimed unit cannot control',
#  'claimed unit not working',
#  'clock synchronization failure',
#  'clt door not closed',
#  'cms environment - both environments down',
#  'cms environment down / crashed (one environment down)',
#  'coin controller board/coin system disable',
#  'coin controller card fuse blown/replacement',
#  'coin drum',
#  'coin drum/coin jammed inside coin drum',
#  'coin handling unit error/coin jammed inside cau',
#  'coin insertion unit replacement/coin slot',
#  'coin slot solenoid/coin insertion unit',
#  'coin tube faulty/cau-nr1 replacement',
#  'coin tube issues',
#  'coin verifier',
#  'coin verifier/coin jammed inside coin verifer',
#  'com failed',
#  'com link error',
#  'comb light flickering',
#  'comms related fault',
#  'communication down between iscs sig / scs pms communication and server ',
#  'condensation',
#  'condensation - from grille',
#  'configuration error ',
#  'connection status shows "connected / not successful" or "connecting..."',
#  'continuity test failure',
#  'continuous bell ringing / buzzer',
#  'cpu card corrupted ',
#  'crack line',
#  'cracked',
#  'crc ac main rocker switch damaged',
#  'crc backup battery failed',
#  'crc failed',
#  'csc r/w / token/csc reader replacement',
#  'csc r/w hanged',
#  'csc r/w hanged/ c through reader hanged',
#  'csc r/w/c-through reader',
#  'csc reader not response',
#  'csc rw/c-through reader replacement',
#  'csc rw/security token/csc rw hanged',
#  'damaged duct/trunking',
#  'data gateway hanged/failed',
#  'data logger related',
#  'dbs environment stop / crashed (one environment down)',
#  'dc  dc converter/ac-dc converter',
#  'dc power supply unit/power supply unit replacement/door power supply module',
#  'dc-dc converter/ac-dc converter/ac-dc module',
#  'dcs enviroment stop / crashed (one environment down)',
#  'dcs environment - both environments down',
#  'dcs/tds alarms in occgws listing or mainline alarms displayed in dccgws.',
#  'dcu data comm problem',
#  'ddc alarm / fault',
#  'default message',
#  'depot fault',
#  'depot traffic schematic turn blue',
#  'detector leakage',
#  'deviced tripped',
#  'different pis library version between train & iscs',
#  'diffusers - dirty',
#  'directional display',
#  'directional display/lcd no display/validation light',
#  'dirty',
#  'display blank',
#  'display colour distorted',
#  'display flickering',
#  'display no train arrival timing',
#  'display screen faulty',
#  'display unable to show priority message',
#  'display with blur image',
#  'display with dialogue box',
#  'display with error message',
#  'display with lines',
#  'display with missing word',
#  'display with no dtl train arrival timing',
#  'display with no ewl train arrival timing',
#  'display with no nel nb train arrival timing',
#  'display with no nel sb train arrival timing',
#  'display with no video ',
#  'display with wrong font size',
#  'display wrong orientation ',
#  'display wrong train arrival timing',
#  'display/ captured obstruction mode during closing',
#  'dms / dmse / hii received / toggling ',
#  'dms affecting signalling equipment/rtu/lan/etc',
#  'dms-adjacent link failure',
#  'dms-atc link failure',
#  'dms-cbi link failure',
#  'dms-iscs link failure',
#  'dms-psd link failure',
#  'do not use',
#  'dom/dom cable/cf card',
#  'door 1 fault',
#  'door 4 fault',
#  'door breaked-in',
#  'door close failed',
#  'door contact faulty',
#  'door fail to open',
#  'door issues',
#  'door latch/ lock',
#  'door lock failed/unknown',
#  'door lock/door switch replacement',
#  'door lock/door switch/limit switch',
#  'door movement slow',
#  'door open failed',
#  'door power pcb drop out/door switch',
#  'door unable to arm',
#  'door unable to close',
#  'door unable to open',
#  'door unable to unarmed',
#  'dpp function failure',
#  'drop bolt alignment issue',
#  'dss icon blinking / trend malfunction',
#  'dvr offline',
#  'dw close & lock loop problem',
#  'dw noisey during movement',
#  'dw part missing',
#  'dw status indicator problem',
#  'dw switches problem',
#  'e1 converter failed',
#  'e1 link faulty',
#  'earth fault activated/ earth fault failure/ monitor table activated/ psd device activated',
#  'ecs environment stop / down / crashed (one environment down)',
#  'ecs equipment cannot be on/off remotely',
#  'ecs equipment in unknown status',
#  'ecs equipment time table download failure',
#  'ecu replacement',
#  'ecu/ecu no power',
#  'eda lost contact/forced active/limitswitch fault',
#  'ehicom interfacing failure',
#  'electric drop bolt faulty',
#  'elh power supply alim_5 failure',
#  'em-lock baseplate dislodged',
#  'em-lock dislodged',
#  'em-lock faulty',
#  'emergency fire phone enclosure faulty',
#  'emergency fire phone not working',
#  'emergency stop button (esb) activated',
#  'encoder #1/unable to issue paper ticket /paper ticket dipenser roller loose',
#  'encoder #2/paper ticket dispenser jammed',
#  'encoder #3/paper ticket dispenser disable/cleaning of the paper ticket dispenser',
#  'encoder/internal cscrw issues',
#  'end equipment/switch cause broardcast loop ',
#  'end equipment/switch network loss of signal',
#  'end return door closing/ opening encountered problem',
#  'environmental defects',
#  'equipment control failure / incorrect control sent',
#  'equipment fault with alarms',
#  'equipment fault without alarm/fault code',
#  'equipment not functioning correctly',
#  'equipment status toggling or alarm received',
#  'equipment ventilation fan not working',
#  'equipment/rack exhaust fan not functioning',
#  'equipment/server lan fault',
#  'equipment/server switchover',
#  'equipment/server/switch switchover',
#  'erm activated',
#  'error ',
#  'error / wrong stabling table information',
#  'error / wrong timetable information',
#  'error message prompted when try to kill the live pa/ atas/dva broadcast message ',
#  'ers-400 not activated',
#  'escalator unable to slow down',
#  'exact fare',
#  'exact fare/card lifter ',
#  'excessive burnt mark',
#  'excessive dust',
#  'excessive wear',
#  'exit push button damaged',
#  'exit push button out of position',
#  'ext reader (err)/ token/c-through reader/reader antenna',
#  'external reader receptalce (err)/ token/c-through reader/token cable/err cable',
#  'external/internal csc reader/external cscrw issues/replacement',
#  'fail to bootup',
#  'fail to continue executing the train wash sequence ',
#  'fail to generate crystal report',
#  'fail to modify the login user account name & password ',
#  'fail to modify the pis schedule or text message ',
#  'fail to reboot',
#  'fail to retrive / archive the alarms or events from database',
#  'fail to switch over from controller',
#  'failed to standby mode',
#  'false platform / train hold applied to train / platform ',
#  'fan alarm',
#  'fan faulty',
#  'fault',
#  'fault alarm',
#  'fault found during pm/ cm/ wbl',
#  'fault related from lru 01 to lru 15',
#  'fault reported during cm',
#  'fault reported during pm',
#  'faulty',
#  'faulty & self recovered',
#  'fb block in ar / nr sttaus / unknown',
#  'fep 1 faulty only',
#  'fep 2 faulty only',
#  'fep board/lru alarms',
#  'fep out of order/sig controller fault status',
#  'filament status is burnt and not proved',
#  'filament status is burnt and proved',
#  'filtering error (when operate the alarm / event / archive function at gws)',
#  'fire alarm',
#  'fire shutter alarm indicated at gws',
#  'fire shutter unable to raise up',
#  'fire shutters activated',
#  'fireman intercom alarm',
#  'fixed block status in nr/ar state',
#  'fixed panel glass shattered',
#  'flap cannot open/close',
#  'flap open and close',
#  'flap rubbing cabinet',
#  'flap/ motor/ gear/cam shaft',
#  'floor plates',
#  'found during pm',
#  'fsfb net related fault',
#  'gama related fault',
#  'gate motor/ups mod cable',
#  'general alarm',
#  'ground alarm',
#  'gtm intercom voice communication not working',
#  'gws - no fault found',
#  'gws - when one station and its adjacent 2 stations gws down',
#  'gws alarm',
#  'gws auto logout',
#  'gws hang / response slow',
#  'gws hard disk available space all or nearly occupied ',
#  'gws keyboard / mouse malfunction',
#  'gws lan status fault / unable to establish connection',
#  'gws login / logout failure',
#  'gws monitor abnormal display',
#  'gws radio session down',
#  'gws radio session toggling / gws gwld link toggling',
#  'gws radio voice call function failure',
#  'gws show blue',
#  'gws shows shutter down ',
#  'hairline cracked/minor cracked',
#  'handover problem--delegation table shows wrong status/animation or incorrect handover event message ',
#  'handrail jerky',
#  'hang',
#  'hang -csc no response',
#  'hang at blank screen',
#  'hang at blue/ blank screen',
#  'hang at loading os/out of service',
#  'hang at os',
#  'hang at ps screen',
#  'hang at vxwork',
#  'hanged',
#  'hardisk/cf card replacement',
#  'having alarm',
#  'having general fault led alarm',
#  'having generic alarm',
#  'having warning led alarm',
#  'hdd adnormal',
#  'heavy arcing',
#  'hgn',
#  'hmi computer faulty',
#  'hmi information / schematic status updating problem',
#  'hmi related fault',
#  'hotline issue (no ring at remote site)',
#  'hscb tripped & ammeter show high reading',
#  'hw interfacing failures (between boards)',
#  'hw related failure (boards failure)',
#  'i/o gp b card failure',
#  'image distoration',
#  'inaccurate or incorrect power telemetry reading',
#  'incorrect alarm severity assigned to equipment ',
#  'incorrect operation mode operated by tvs',
#  'incorrect operation mode proposed',
#  'incorrect pec activated status shown on train inspector panel or gws ',
#  'incorrect timing used in regulation mode control',
#  'incorrect train readiness / driving mode performed by train',
#  "incorrect train service's trip execution or trip service not realized at platform",
#  'indicator bulb no lit up',
#  'information of train arrival / departure information table not updated / not correct',
#  'installation defect',
#  'int glass (w/o esp) shattered',
#  'intercom unit drop out/intercom matters',
#  'invalid attempt',
#  'invalid or non existence train information appears in train window',
#  'invisible hold',
#  'iscs related fault',
#  "iscs rtu links shown 'red'",
#  'iscs to ecs communication error',
#  'isolation indication',
#  'itama/ gitama grant / withdraw  failure',
#  'itama/gitama grant/withdraw failure or lost',
#  'jam card at nets reader',
#  'jerky',
#  'keep on displaying the same alarm on the alarm / event panel even it was acknowledged',
#  'key hole on switch cover loosen',
#  'key lock jammed',
#  'key switch activated',
#  'keyboard failure/maintenance panel issues',
#  'keyboard failure/maintenance panel replacement',
#  'keyboard faulty',
#  'keyboard/mouse',
#  'keyboard/mouse not responding',
#  'knocking sound',
#  'launching table loading error / failure',
#  'lcd display/22"lcd monitor display',
#  'leakage',
#  'led display blank/hang',
#  'lift homing',
#  'lift not levelled',
#  'lift out of order',
#  'link fail alarm - eth a ',
#  'link failure between system',
#  'link health status - fault ',
#  'link lost with tdms',
#  'link lost with tims/tcms',
#  'login terminal (sui) faulty/ maintenance panel',
#  'loose',
#  'loose connection',
#  'loose parts observed at dw',
#  'loose parts observed at end return',
#  'loosen and unable lock/secure',
#  'lost train movement direction',
#  'lost train pti data or train runs on wrong pti data',
#  'loud noise',
#  'low voltage',
#  'lscavc001-avc rectifier system minor fault',
#  'lscavo001-scd bay minor fault',
#  'lscavo002-scd bay major fault',
#  'lscavo003-sd bay minor fault',
#  'lscavo004-sd bay major fault',
#  'lscavo005-sd box minor fault',
#  'lscavo007-scd test control terminal fault',
#  'lscavp001-avp/vd bay minor fault',
#  'lscavp002-avp/vd bay major fault',
#  'lscavp003-mso bay minor fault',
#  'lscavp005-relay bay minor fault',
#  'lscavp007-mt bay fault',
#  'lscavs001-avs computer bay minor fault',
#  'lscavs007-avs workstation fault',
#  'lsccbi001-interlocking bay minor fault',
#  'lsccbi003-et bay minor fault',
#  'lsccbi006-switch machine fault',
#  'lscobv001-avp controller major fault',
#  'lscobv003-vd transmitter major fault',
#  'lscobv005-avp controller minor fault',
#  'lscobv006-avp receiver minor fault',
#  'lscobv007-vd transmitter minor fault',
#  'lscobv008-avo controller major fault',
#  'lscobv009-station avo major fault',
#  'lscobv010-avo controller minor fault',
#  'lscobv011-station avo minor fault',
#  'lscobv012-vis db (nfb) trip',
#  'lscobv013-vis fault',
#  'm211 clock failure',
#  'm211 loss of power ',
#  'm211 loss of synchronization ',
#  'm211 octal serial module 1: no output',
#  'm355 display segment faulty/blank',
#  'm842 acu main m211 status alarm',
#  'm842 acu standby m211 status alarm',
#  'magazine 1/change notebox',
#  'main failure alarm',
#  'main interface card/secondary interface card/pcb board/plc comms card/ i/o card',
#  'maintenance code not executed ',
#  'major alarm at gws, cbn equipment',
#  'man trap',
#  'manager software auto restart',
#  'mbcc lost comm.',
#  'mcb tripped/circuit breaker faulty',
#  'microphone is faulty',
#  'minor alarm at gws, link to other end equipment user failed',
#  'miscellaneous',
#  'missing / wrong pec caller id displayed on the calling banner',
#  'missing / wrong radio caller id displayed on the calling banner',
#  'mms oracle package not running',
#  'monitor faulty',
#  'mouse fault',
#  'mpu/ttk ecu replacement',
#  'mute cab',
#  'na-other hardware faults',
#  'nets counter',
#  'nets power adapter',
#  'nets terminal',
#  'network equipment hang',
#  'network error',
#  'network loss of signal',
#  'network switch failed',
#  'niap/ap related fault',
#  'no audible overspeed alarm',
#  'no audio',
#  'no chime when broadcasting dva',
#  'no chime when broadcasting live broadcast ',
#  'no com/com error',
#  'no comms',
#  'no comms /out of service',
#  'no comms to afc equipment',
#  'no comms with sc/gui',
#  'no communication',
#  'no data sent from iscs to mms / no communications',
#  'no defects found',
#  'no display',
#  'no display on indicator',
#  'no display/bad display',
#  'no fan',
#  'no fault found',
#  'no input power source ',
#  'no light',
#  'no pa announcement heard ',
#  'no power',
#  'no powering',
#  'no radio signal',
#  'no recording',
#  'no response',
#  'no response to platform hold / train hold',
#  'no stt issued/no paper ticket issued',
#  'no symptom',
#  'no trainborne alarm received / wrong location of trainborne alarms received',
#  'no ventilation',
#  'no video',
#  'no/intermittent  atas/pa/dva',
#  'noise/metallic/distortion of audio quality',
#  'noisy',
#  'non ecs fault',
#  'non signal fault',
#  'non-liable',
#  'normal wear',
#  'not detected ',
#  'notebox problems/coinbox problem/unable to detect notebox/unable to detect coinbox',
#  'null',
#  'oil stain',
#  'on-board communication failure with c760',
#  'one way voice communication',
#  'only rm available',
#  'opd project screen black out / abnormal display',
#  'operating system not responding',
#  'operator cannot accept the pec ',
#  'oracle program stop / crashed',
#  'other fault',
#  'other hardware fault',
#  'other hardware faults',
#  'other hardware faults/other hardware problems',
#  'other link failure',
#  'other pabx faults',
#  'other psm printer problems',
#  'other software faults',
#  'other software faults ',
#  'other software faults/auto rebooting',
#  'other symptom not in the list',
#  'others',
#  'others-train interfacing problem',
#  'out of operation/ faulty',
#  'out of service',
#  'overrun  at station/sidings',
#  'overrun station',
#  'overshoot',
#  'pa broadcasting fail with / without error message',
#  'pa broadcasting to train failure',
#  'pabx major alarm',
#  'pabx minor alarm',
#  'panel dangling',
#  'paper ticket jammed/shutter closed/ticket dispenser feeder problem',
#  'parameters set for cctv image viewing or recording are lost / corrupted ',
#  'parts missing',
#  'pas message execution stuck in "connecting" in gws ',
#  'pas playback ad-hoc message from main handset, nothing heard ',
#  'pas rack fan alarm ',
#  'passenger feedback temperature warm',
#  'pat/power supply unit replacement',
#  'patron information display/ pid no display',
#  'patron sensor',
#  'patron sensor alignment out/gate intrusion',
#  'patron sensor alignment out/patron sensor blocked/gate intrusion/cleaned sensor',
#  'patron sensor faulty',
#  'pax comfort (for external reported fault. smooth, cooling, bright  and quiet ride.)',
#  'pdu display dim/pdu no display',
#  'pdu display dim/pdu no display/pdu replacement',
#  'pec no way voice communication (no background noise)',
#  'pec one way communication ',
#  'pec one way voice communication',
#  'pec unable to communication',
#  'pedc failed/ toggling/ chattering/ link with dms down',
#  'peu remote controller cover broken',
#  'peu remote controller cover came off',
#  'peu remote controller faulty loose',
#  'pid / ld intermittent display information',
#  'pid no display/pid replacement/csc cover replacement',
#  'pid text message display fail with / without error message',
#  'pid time sequencing fault',
#  'pilot wire fault alarm',
#  'platform hold / train hold command set failure',
#  'playback dva message from main handset, nothing heard ',
#  'plc fault / toggling / mux input / mux selection fault',
#  'pneumatic system spiral cable hanging loosely',
#  'pneumatic system spiral coil overstretched',
#  'point failed at reverse side  ',
#  'point failed during route setting',
#  'point failed once (route setting)',
#  'point lost detection by itself',
#  'point parts loose',
#  'point unable to detect during exercise',
#  'point unable to exercise (remote)',
#  'poor radio signal',
#  'port faulty ',
#  'power fail ',
#  'power failure',
#  'power reset and test ok',
#  'power supply',
#  'power supply failed',
#  'power supply faulty/power supply connection',
#  'power supply tripped',
#  'power supply unit (24vdc)/power managment unit',
#  'power trip',
#  'precautionary checks',
#  'printer belt replacement/printer issue',
#  'printer belt/printer sensor/bna belt misaglined',
#  'printer comms cable drop out/replacement',
#  'printer paper jam/not inserted/keep on printing',
#  'printer paper jammed/unable to print receipt/printer problem',
#  'printer paper low',
#  'printer replacement',
#  'printer replacement/ctk printer replacement',
#  'process of the system environment down / crashed',
#  'psc mic audio not clear/no sound',
#  'psc scp buzzer cannot switch off',
#  'psc unable to operate sef',
#  'psc vcp screen - very blur',
#  'psc vcp unable to control',
#  'psd bypass/ isolate switch not working',
#  'psd door indicator light',
#  'psd door status faulty & bypassed / toggling',
#  'psd manual open/ close switch not working',
#  'psd open and close a few times',
#  'psd schematic not updating',
#  'psm cpu/psm pc/cpu',
#  'psm printer replacement',
#  'psm printer/psm printer jammed',
#  'psm slow in response',
#  'pti initialization request -- failed with bad return condition',
#  'public feedback',
#  'public incident',
#  'rack fan alarm',
#  'rack fan noisy/faulty',
#  'radio connection status problem ',
#  'radio equipment lan fault',
#  'radio error message',
#  'radio incoming / outgoing call stack cannot be cleared / released',
#  'radio session down / detached / disconnected',
#  'rch hang at boot screen/blank',
#  'readiness mode change failure',
#  'redman error display : others',
#  'redman error display : x003',
#  'redman error display : x084',
#  'redman error display : x085',
#  'related to fixed block in ar / nr state',
#  'reload /reset plc software/ plc  error',
#  'reload plc software/ reset plc/reset vsc',
#  'replacement of flap/gear',
#  'replacement of maintenance panel',
#  'replacement of paper ticket dispenser',
#  'replacement of vsc/replacement of plc/plc battery replacement',
#  'rms/mss application not responding',
#  'rms/mss cannot boot up',
#  'rms/mss operating system not responding',
#  'roller shutter jerking when in operation',
#  'roller shutter malfunction',
#  'roller shutter motor brake faulty',
#  'roller shutter unable to open fully',
#  'roller shutter unable to operate',
#  'rotating slow with noise',
#  'route / dispatch / hii mode selection failure',
#  'route / manoeuver abnormal auto set / unset ',
#  'route call by system',
#  'route or manoeurve not follow the departure ctrl time to set / unset ',
#  'route set / unset control failure',
#  'route set/unset control failure',
#  'route setting related ',
#  'route unable/not set',
#  'router - fault alarm not affecting switch operations',
#  'router failed',
#  'routers - when 1 station/iocc/depot routers down',
#  'routers - when one or both the station routers down (for same location)',
#  'routing error ',
#  'rs related fault',
#  'rs2x disable/notebox id issue/coinbox issue',
#  'rs2x disable/notebox issue',
#  'rtu - 1 rtu down',
#  'rtu - when one or both rtu down in the same location',
#  'rtu fault',
#  'rtu fault / toggling / serial / peer link fault',
#  'rtu lan status fault',
#  'rtu network equipment down / toggling (1 side down only)',
#  'rtu switch over / reset failure',
#  'safety edge rubber misalignment',
#  'safety gauge faulty',
#  'same cctv alarm referenced to two toggling car numbers in same train ',
#  'sbc fan/ecu/mouse/keyboard/ ctk ecu replacement',
#  'scdf intercom alarm',
#  'scp panel door cannot open',
#  'seal broken/vandalism/damage',
#  'securnet unable to login',
#  'selected higher priority text message cannot be display ',
#  'self recover',
#  'self recovered',
#  'self recovery/ recovered by station staff',
#  'self recovery/recovered by station staff',
#  'server environment - when both environments down',
#  'server hanged/failed',
#  'server hdd failed',
#  'shutter jammed during operation',
#  'shutter slabs uneven when in operation',
#  'signal strength issue ',
#  'signs of deterioration',
#  'skip station',
#  'slant',
#  'slip',
#  'slow',
#  'smell',
#  'smelly',
#  'smoke curtain activated',
#  'smoke curtain cannot be reset.',
#  'smoke curtain did not descend when activated',
#  'smoke curtain entangled',
#  'smoke curtain not aligned with ceiling panel.',
#  'smoke curtain unable to  retrieve',
#  'smoke curtain unable to retrieve',
#  'sms -  no fault found',
#  'sms server lan status fault',
#  'sms server redundancy fail',
#  'sms server switchover failure',
#  'software web access problem',
#  'some dw unable to close',
#  'some dw unable to open/ not fully open',
#  'stabling table loading error / failure',
#  'static electric shock',
#  'station fire alarm icon abnormal blinking / wrong status',
#  'station public / paid area stuffy / warm',
#  'station server environment stop / down (one environment down)',
#  'status signal',
#  'stop rotating',
#  'strike plate damaged',
#  'strike plate out of alignment',
#  'stuck',
#  'stuck at initial mode',
#  'stuck at initialization mode',
#  'stuck at prepared mode',
#  'subsection : tsr modification status - rejected alarm',
#  'summary indicator faulty',
#  'supervisory console hanged/failed',
#  'sw related fault',
#  'swc communication link fault',
#  'swing gate',
#  'swing gate (reprogram)/error',
#  'swing gate adjustment/ replacement/swing gate pcba board',
#  'swing gate error/ hanged',
#  'swing gate error/ lock loose',
#  'switch - fault alarm not affecting router operations',
#  'switch - when 1 switch down',
#  'switch - when one or both the station switches down (for same location)',
#  'switchgear gas alarm',
#  'switchover not executed',
#  'system fault alarm ',
#  'system keep delaying departure time, idt has to be issued by operator',
#  'tci communication through radio failure',
#  'tci failure alarm',
#  'telephone damaged (cracked, etc)',
#  'telephone not ringing',
#  'telephone not working / no dial tone',
#  'telephone socket damaged',
#  'temperature',
#  'temperature alarm',
#  'temperature notcold',
#  'temperature too cold',
#  'temperature too high',
#  'tetra radio faulty',
#  'ticket jammed/paper ticket jammed',
#  'ticket sensor/paper ticket dispenser sensor',
#  'ticket transporter card/roller/paper ticket dispenser replacement',
#  'ticket transporter/roller/paper ticket dispenser',
#  'time not synchronize',
#  'timer out of setting',
#  'timetable loading error / failure',
#  'toggling problem',
#  'token issues/tcsam issues',
#  'top led display',
#  'top led display replacement',
#  'top led error',
#  'touch screen faulty/lcd monitor/replacement of the touch panel assembly',
#  'touch screen no comms or no response/ controller board error/22" lcd monitor',
#  'touch screen no respone/lcd monitor no display/lcd display blur/touch panel calibration out',
#  'touch screen no response/touch screen error',
#  'touch screen problem/display screen dim/lcd display screen blurred',
#  "touch screen/ controller board/ 22' lcd monitor replacement",
#  'touchscreen hanged',
#  'track circuit down',
#  'track circuit out of operation',
#  'track circuit shows incorrect route set / unset status',
#  'track circuit status toggling',
#  'train & psd door not synchronised',
#  'train & psd doors did not open',
#  'train and psd sychronise fault',
#  'train arrival / departure time control failure',
#  'train delocalise/niap caused by trainborne system',
#  'train door / psd abnormal operation',
#  'train dr open/psd cannot open & vice versa',
#  'train fails to coe (change of end)',
#  'train in unknown status',
#  'train launching failure',
#  'train localisation / delocalised problem or error',
#  'train lost pti data or train runs on wrong pti data ',
#  'train missed beacon(s)',
#  'train overrun / underun the platform when approaching to platform',
#  'train overrun/underrun (special occurrence)',
#  'train pec fail to be activated ',
#  'train readiness mode selection failure',
#  'train selection failure',
#  'train speed slow,unable to obtain full speed',
#  'train stable at wrong location',
#  'train stall / eb (special occurrence)',
#  'train stalled,unable to depart(issue idt still cannot depart)',
#  'train stalled,unable to depart(issue idt)',
#  'train tripped/eb applied',
#  'train unable to depart due to dw fault',
#  'train unable to detect stib / psbd',
#  'train unable to receive schedule',
#  'train unable to wake up by time-table schedule',
#  'train wake up / sleep control failure',
#  'train wash problem',
#  'train window toggling(communication toggling)',
#  'train/vehicle/equipment fault with alarms ( reported by gws/mac log/vdu)',
#  'train/vehicle/equipment fault without alarm/fault code (reported by staff)',
#  'trainborne atc communication lost / toggling',
#  'trainborne communication functions failure',
#  'trains delocalised cause by trackside system',
#  'tripped',
#  'tsr / gtsr set / reset fail /spks',
#  'tsr related fault',
#  'tsr related problem',
#  'tsr/ gtsr / spks set/ reset failure ',
#  'ttcu related fault',
#  'tvf - negative mode',
#  'tvs - silencer perforated sheet dislodged.',
#  'ule non-active',
#  'unable to achieve auto mode',
#  'unable to achieve mainline off service mode',
#  'unable to auto sleep',
#  'unable to boot up',
#  'unable to broadcast cyclical dva message (dna system)',
#  'unable to changeover',
#  'unable to close',
#  'unable to control from sc/gui',
#  'unable to execute ad-hoc message (dna system)',
#  'unable to execute dva',
#  'unable to execute live announcement ',
#  'unable to execute the gong + talk function (dna system)',
#  'unable to execute the monitor function',
#  'unable to grant/receive itama',
#  'unable to hear any broadcast ',
#  'unable to login',
#  'unable to make ad-hoc broadcast at gws ',
#  'unable to make live broadcast',
#  'unable to move',
#  'unable to move in am ,cm but rm ok',
#  'unable to move/change in auto',
#  'unable to move/change in cm ',
#  'unable to open',
#  'unable to operate',
#  'unable to playback message',
#  'unable to proceed after granting itama',
#  'unable to read the display',
#  'unable to receive skip command',
#  'unable to record ad-hoc message',
#  'unable to select zone to make live annoucement ',
#  'unable to start',
#  'unable to start up the manager software',
#  'unable to switch/control occ wall monitor rms',
#  'unable to view cctv',
#  'unable to withdraw itama',
#  'underrun at station/sidings',
#  'unexpected controls activated / de-activated -- itama/gama/ggama/spks/tsr',
#  'unexpected handover occuring on the functions',
#  'unexpected skip stop the platform',
#  'unexpected train interstation stalled status received ',
#  'unit - on & off',
#  'unit alarm',
#  'unit not running',
#  'unit running',
#  'unit running when not off',
#  'unit running with unknown activation',
#  'unit trip',
#  'ups failure/replacement/plc error',
#  "user can't login to mms through oa lan",
#  'user cannnot create tar',
#  'user not able to use wonderware software on bms ws',
#  'value not added',
#  'vis minor fault',
#  'vp board failure',
#  'warm',
#  'water dripping',
#  'water dripping / leaking',
#  'water high level alarm',
#  'water leakage',
#  'water leaking',
#  'water low level alarm',
#  'water over flow alarm',
#  'water ponding',
#  'wbs link status toggling',
#  'wrong / lost train direction displayed on gws / opd',
#  'wrong alarm / event description mapping between c755 database and swc ',
#  'wrong alarm status displayed on train alarm status bar ',
#  'wrong application in sc ',
#  'wrong code selected',
#  'wrong connection',
#  'wrong train pti data send',
#  'xy out of tolerance',
#  'zone sound distorted',
#  'zone sound level is too high',
#  'zone sound level is too soft ']

# %%
# Append other non-indicative class and remove them
tmp_list = ['others', 'miscellaneous', 'fault', 'other symptom not in the list', 'no symptom', 'wrong code selected', 
          'no fault found', 'other fault', 'all other faults not listed', 'other hardware fault', 'other hardware faults', 'faulty',
          'other software faults', 'na-other hardware faults', 'other link failure','other pabx faults', 'other psm printer problems', 
          'other hardware faults/other hardware problem','other hardware faults/other hardware problems', 'other link failure',
          'other software faults/auto rebooting', 'other software faults ', 'no defects found']

train_df = train_df[~train_df["TARGET"].isin(tmp_list)]
train_df = train_df[~train_df["TARGET"].str.contains('do not use', case=False, regex=True)]

# %%
# Keep class that where >= 10
value_counts = train_df['TARGET'].value_counts()
keep = value_counts[value_counts >= 10].index
train_df = train_df[train_df['TARGET'].isin(keep)]
train_df = train_df.reset_index(drop=True)

# %%
train_df.head()
# Out:
#                                                NOTES                                    NOTES_PROCESSED                                             TARGET
# 0  Fault: Intrusion alarm.  Corrective action: On...  intrusion alarm corrective site service checke...  patron sensor alignment out/patron sensor bloc...
# 1  Fault: No comm Corrective action: On site mach...  comm corrective site machine degraded mode unp...                                           no comms
# 2  Fault : CSC RW error Corrective action  AFC ga...  csc rw error corrective afc gate service site ...                           csc r/w/c-through reader
# 3  Fault: NBX unable to initialise.  Corrective a...  nbx unable initialise corrective site service ...                          magazine 1/change notebox
# 4  Fault : Intermtent cannot accept notes Correct...  accept note corrective ttk service site cleanu...          self recovery/ recovered by station staff

# %% [markdown]
# ### b. Testing Dataset

# %%
# Apply fucntion
test_df['NOTES'] = test_df['NOTES'].apply(clean_notes)
test_df['NOTES_PROCESSED'] = test_df['NOTES'].apply(remove_punctuation)
test_df['NOTES_PROCESSED'] = test_df['NOTES_PROCESSED'].apply(remove_stopwords_lemmatize)
test_df['NOTES_PROCESSED'] = test_df['NOTES_PROCESSED'].apply(filter_noise)

# %%
# Remove any that contain only 1 word or are empty 
test_df['NOTES_PROCESSED'] = test_df['NOTES_PROCESSED'].apply(lambda x:''.join(x))
test_df['LENGTH'] = test_df['NOTES_PROCESSED'].apply(lambda x: len(x.split()))
test_df = test_df[test_df['LENGTH']>1]
test_df = test_df.reset_index(drop=True)

# Reshuttle cols
test_df = test_df.drop('LENGTH', axis=1)
test_df = test_df[['NOTES','NOTES_PROCESSED','TARGET']] #reshuffle cols

# %%
# Convert to lower case, remove non indicative class
test_df['TARGET'] = test_df['TARGET'].apply(lambda x: x.lower())
test_df = test_df[~test_df["TARGET"].isin(tmp_list)]
test_df = test_df[~test_df["TARGET"].str.contains('do not use', case=False, regex=True)]

# %%
# Keep class that where >= 10
value_counts = test_df['TARGET'].value_counts()
keep = value_counts[value_counts >= 10].index
test_df = test_df[test_df['TARGET'].isin(keep)]
test_df = test_df.reset_index(drop=True)

# %%
test_df.head()
# Out:
#                                                NOTES                                    NOTES_PROCESSED                                             TARGET
# 0  Fault: Gate show "X" on screen.  Corrective ac...  gate show x screen corrective site service sc ...                                    ecu replacement
# 1  Fault: Gate showing "X" on the screen.  Correc...  gate showing x screen corrective site oos sc s...                                    ecu replacement
# 2  Fault : Intrusion alarm Corrective action : AF...  intrusion alarm corrective afc gate service si...  patron sensor alignment out/patron sensor bloc...
# 3  Fault : Patron sensor error Corrective action ...  patron sensor error corrective afc gate servic...         patron sensor alignment out/gate intrusion
# 4  Fault : Intrusion error intermittent Correctiv...  intrusion error intermittent corrective gate s...  patron sensor alignment out/patron sensor bloc...

# %% [markdown]
# ## 5. Train Test Split

# %%
x_train = train_df[['NOTES_PROCESSED']]
y_train = train_df['TARGET']

# %%
x_test = test_df[['NOTES_PROCESSED']]
y_test = test_df['TARGET']

# %% [markdown]
# ## 6. Vectorizer

# %% [markdown]
# #### a. COUNT VECTORIZER

# %% [markdown]
# denoted as CV

# %%
cv = CountVectorizer()
x_train_cv = cv.fit_transform(x_train['NOTES_PROCESSED'])
x_test_cv = cv.transform(x_test['NOTES_PROCESSED'])

# %% [markdown]
# #### b. TF-IDF VECTORIZER

# %% [markdown]
# denoted as TFIDF

# %%
TFIDF = TfidfVectorizer()
x_train_TFIDF =  TFIDF.fit_transform(x_train['NOTES_PROCESSED'])
x_test_TFIDF = TFIDF.transform(x_test['NOTES_PROCESSED'])

# %% [markdown]
# #### c. Word2Vec

# %% [markdown]
# denoted as W2V

# %%
# Tokenise NOTES_PROCESSED
train_df['NOTES_PROCESSED_TOKENIZE'] = [nltk.word_tokenize(i) for i in train_df['NOTES_PROCESSED']]

# %%
# Model initialization, building its vocabulary
w2v_model=Word2Vec(train_df['NOTES_PROCESSED_TOKENIZE'],min_count=1)

# %%
# Convert word2Vec trained model vocabulary into a dict with embeding
w2v_dict = dict(zip(w2v_model.wv.index_to_key, w2v_model.wv.vectors))

# %%
print(list(zip(w2v_model.wv.index_to_key, w2v_model.wv.vectors)))
# Out:
# [('ok', array([ 1.1660984 , -0.03065811,  1.9209181 ,  0.7938896 ,  0.92676604,
#        -1.4401073 ,  1.5002825 ,  0.6079389 , -0.7051554 , -0.3875992 ,
#        -2.065837  ,  0.23475893, -0.3418075 ,  1.1932448 ,  0.12915716,
#        -1.5636638 ,  0.35889068,  0.257231  , -0.9942395 ,  0.9692831 ,
#         0.48034593,  0.9875737 , -1.2968978 ,  0.3162537 ,  1.2244487 ,
#        -1.2127877 , -0.02825627, -0.2366609 , -1.0251863 , -1.2940786 ,
#        -2.9890823 , -0.7017514 , -0.10709849,  0.22828852, -0.08443444,
#        -1.3128179 ,  1.5188534 , -0.95872784,  1.5835767 ,  0.5385361 ,
#        -0.23000981, -1.1034659 , -0.41649505, -0.00786071,  1.8988334 ,
#         1.2914392 , -0.20993516,  1.3417904 ,  2.612468  ,  0.5255507 ,
#         0.36388022,  1.2039891 ,  0.6162181 ,  0.09935987, -0.8756703 ,
#        -0.281449  ,  2.2149832 , -1.2253712 , -1.2536186 , -1.3650761 ,
#        -0.22839361,  0.89750165, -0.17950788,  0.14887668,  0.24342862,
#         0.26600912, -0.22737412,  0.9996464 , -0.23418875,  0.9620844 ,
#        -0.20862435,  0.5903658 , -0.28652677, -3.019859  ,  1.0449822 ,
#        -0.13823508,  1.1599331 , -0.25413626,  0.12964918, -0.13191885,
#         0.4506638 , -0.08961082, -0.28215498, -0.8873037 ,  0.17973864,
#        -0.71928835,  1.3832353 ,  0.8298739 , -1.2196602 ,  1.9447256 ,
#         0.03435136, -1.1304634 , -0.15138021,  1.2797526 , -1.1435806 ,
#         1.4139904 , -0.9046483 ,  1.7267996 , -0.7408371 ,  2.219549  ],
#       dtype=float32)), ('car', array([-1.2333099 ,  0.5464463 , -1.0162302 ,  0.04988582,  0.84537816,
#        -0.9616883 , -0.46286803,  0.84828544,  0.37555656,  0.05274868,
#        -0.10253838,  0.3671425 , -0.9558212 , -0.11427582,  0.3361249 ,
#         1.3771678 ,  0.4813995 ,  0.46410462, -0.61652154,  0.12560394,
#        -0.06850442,  1.0435708 ,  1.7978914 ,  0.52253735, -1.3150638 ,
#        -1.0977887 , -0.78784996, -0.8929018 , -0.13826802, -0.65293497,
#        -2.11194698e-02, -6.13615243e-03, -2.89800745e-02,  3.45829129e-02,
#         1.13096908e-02, -8.97919480e-03,  2.26890109e-02, -9.32452362e-03,
#        -3.91634777e-02,  9.78884567e-03,  5.05696423e-03,  4.05891575e-02,
#        -4.09098482e-03,  2.74003819e-02,  2.66474974e-03,  3.12344469e-02,
#         1.66864078e-02,  1.56126581e-02, -3.56337661e-03, -6.09402265e-03,
#         1.67173464e-02, -1.57105899e-03, -1.45182488e-02,  1.41973617e-02,
#         5.14015742e-03, -1.42612206e-02, -4.35758345e-02,  2.36234087e-02,
#        -4.25256928e-03, -1.31321363e-02,  2.44693775e-02,  2.35799477e-02,
#         5.21135889e-03,  1.33404685e-02,  2.10337453e-02,  1.66759826e-02,
#         3.89095256e-03,  2.49048602e-02,  7.96223030e-05,  8.67970660e-03,
#         2.84219924e-02, -1.74059235e-02,  1.69328582e-02,  3.48245469e-03],
#       dtype=float32))]

# %%
# Call the function w2v_dict to return either average or zero vector
w2v = MeanEmbeddingVectorizer(w2v_dict)

# %%
# Tokenise NOTES_PROCESSED
X_train_tok = [nltk.word_tokenize(i) for i in x_train['NOTES_PROCESSED']]  
X_test_tok = [nltk.word_tokenize(i) for i in x_test['NOTES_PROCESSED']]

# %%
# Convert to numerical vector represersentations
X_train_w2v = w2v.transform(X_train_tok)
X_test_w2v = w2v.transform(X_test_tok)

# %% [markdown]
# #### d. Doc2Vec

# %% [markdown]
# denotated as D2V

# %%
# Train Test Split
train = train_df
test = test_df

# %%
# Create Tagged Documents for Doc2Vec
train_tagged = train.apply(lambda r: TaggedDocument(words = tokenize_text(r['NOTES_PROCESSED']), tags=[r.TARGET]), axis=1)
test_tagged = test.apply(lambda r: TaggedDocument(words = tokenize_text(r['NOTES_PROCESSED']), tags=[r.TARGET]), axis=1)

# %%
# Model initialization, building its vocabulary
model_dbow = Doc2Vec(dm = 0, vector_size = 100, min_count=2, alpha=0.025)
model_dbow.build_vocab([x for x in train_tagged.values])

# %%
# Training models
epochs = range(15)
for epoch in epochs:
    print(f'Epoch {epoch+1}')
    model_dbow.train(train_tagged, total_examples = model_dbow.corpus_count, epochs = model_dbow.epochs)
    model_dbow.alpha -= 0.00025
    model_dbow.min_alpha = model_dbow.alpha
# Out:
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15

# %%
# Generate numerical vector represersentations
y_train_d2v, X_train_d2v = vec_for_learning(model_dbow, train_tagged)
y_test_d2v, X_test_d2v = vec_for_learning(model_dbow, test_tagged)

# %% [markdown]
# ## 7. Machine Learning Models

# %% [markdown]
# #### a. Navie Bayes

# %%
nb = MultinomialNB()
param_grid = {
    'alpha': [0.1, 0.5, 1.0, 2.0, 5.0]}
train_model(nb, 'Count Vectorizer', x_train_cv, y_train, x_test_cv, y_test, param_grid)
train_model(nb, 'TF-IDF Vectorizerr', x_train_TFIDF, y_train, x_test_TFIDF, y_test, param_grid)
# Out:
# Vectorizer = Count Vectorizer, Accuracy = 75.49%
# Vectorizer = TF-IDF Vectorizerr, Accuracy = 67.21%

# %% [markdown]
# ### b. SVM

# %%
svc = SVC()
param_grid = {
    'C': [0.1,1,10]}
train_model(svc, 'Count Vectorizer', x_train_cv, y_train, x_test_cv, y_test, param_grid)
train_model(svc, 'TF-IDF Vectorizer', x_train_TFIDF, y_train, x_test_TFIDF, y_test, param_grid)
train_model(svc, 'Word2Vec', X_train_w2v, y_train, X_test_w2v, y_test, param_grid)
train_model(svc, 'Doc2Vec', X_train_d2v, y_train_d2v, X_test_d2v, y_test_d2v, param_grid)
# Out:
# Vectorizer = Count Vectorizer, Accuracy = 85.7%
# Vectorizer = TF-IDF Vectorizer, Accuracy = 88.66%
# Vectorizer = Word2Vec, Accuracy = 77.84%
# Vectorizer = Doc2Vec, Accuracy = 87.24%

# %% [markdown]
# ### c.  Logistics Regression

# %%
# Solver = liblinear
lr = LogisticRegression(solver = 'liblinear', random_state=42)
param_grid = {
    'C': [0.1,1,10], 'max_iter': [100,200]}
train_model(lr, 'Count Vectorizer', x_train_cv, y_train, x_test_cv, y_test, param_grid)
train_model(lr, 'TF-IDF Vectorizer', x_train_TFIDF, y_train, x_test_TFIDF, y_test, param_grid)
train_model(lr, 'Word2Vec', X_train_w2v, y_train, X_test_w2v, y_test, param_grid)
train_model(lr, 'Doc2Vec', X_train_d2v, y_train_d2v, X_test_d2v, y_test_d2v, param_grid)
# Out:
# Vectorizer = Count Vectorizer, Accuracy = 91.03%
# Vectorizer = TF-IDF Vectorizer, Accuracy = 81.13%
# Vectorizer = Word2Vec, Accuracy = 77.64%
# Vectorizer = Doc2Vec, Accuracy = 85.55%

# %% [markdown]
# ## d. Random Forest

# %%
rf = RandomForestClassifier(random_state=42)
param_grid = {
    'n_estimators': [100, 200],            
    'max_depth': [None, 10, 20],            
    'min_samples_split': [2, 5],              
    'min_samples_leaf': [1, 2]}
train_model(rf, 'Count Vectorizer', x_train_cv, y_train, x_test_cv, y_test, param_grid)
train_model(rf, 'TF-IDF Vectorizer', x_train_TFIDF, y_train, x_test_TFIDF, y_test, param_grid)
train_model(rf, 'Word2Vec', X_train_w2v, y_train, X_test_w2v, y_test, param_grid)
train_model(rf, 'Doc2Vec', X_train_d2v, y_train_d2v, X_test_d2v, y_test_d2v, param_grid)
# Out:
# Vectorizer = Count Vectorizer, Accuracy = 97.02%
# Vectorizer = TF-IDF Vectorizer, Accuracy = 97.2%
# Vectorizer = Word2Vec, Accuracy = 96.82%
# Vectorizer = Doc2Vec, Accuracy = 89.89%

# %% [markdown]
# ## e. XGBoost

# %%
xg = XGBClassifier(random_state=42)
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [3, 6],
    'learning_rate': [0.01, 0.1],
    'subsample': [0.7, 1.0],
    'colsample_bytree': [0.7, 1.0]} 
xgb_train_model(xg, 'Count Vectorizer', x_train_cv, y_train, x_test_cv, y_test, param_grid)
xgb_train_model(xg, 'TF-IDF Vectorizer', x_train_TFIDF, y_train, x_test_TFIDF, y_test, param_grid)
xgb_train_model(xg, 'Word2Vec', X_train_w2v, y_train, X_test_w2v, y_test, param_grid)
xgb_train_model(xg, 'Doc2Vec', X_train_d2v, y_train_d2v, X_test_d2v, y_test_d2v, param_grid)
# Out:
# Vectorizer = Count Vectorizer, Accuracy = 88.81%
# Vectorizer = TF-IDF Vectorizer, Accuracy = 92.32%
# Vectorizer = Word2Vec, Accuracy = 95.3%
# Vectorizer = Doc2Vec, Accuracy = 80.04%

# %% [markdown]
# Best Model: Random Forest with TF-IDF Vectorizer (Accuracy 97.2%)

# %% [markdown]
# ## 8. Results

# %%
# Get predictions
train_model(rf, 'TF-IDF Vectorizer', x_train_TFIDF, y_train, x_test_TFIDF, y_test, param_grid)
pred = rf.predict(x_test_TFIDF)
pred_df = pd.DataFrame(pred, columns=['PREDICTION'])
test_df = test_df.reset_index(drop=True)
results = pd.concat([test_df, pred_df], axis=1)
results = results[['NOTES', 'NOTES_PROCESSED', 'TARGET', 'PREDICTION']]
# Out:
# Vectorizer = TF-IDF Vectorizer, Accuracy = 97.2%

# %%
results.sample(5)
# Out:
#                                                   NOTES                                    NOTES_PROCESSED                                             TARGET                                         PREDICTION
# 2938  NEL-FM-2022110060  STATION HAVING POWER SHUTDO...  nel fm station power shutdown testing cause au...                                              noisy                                              noisy
# 1287  Date & Time : 280822 / 0641hrs Location : ML C...  date time ml saloon smoke detection summary st...  train/vehicle/equipment fault with alarms ( re...  train/vehicle/equipment fault with alarms ( re...
# 3720  Follow up NEL-FWC-2022120102/WO 985292: Car 73...  follow nel fwc wo car door check car door foun...  train/vehicle/equipment fault without alarm/fa...  train/vehicle/equipment fault without alarm/fa...
# 1101  PM Train; Found car 72007 PCE1 lockout. 72007 ...  pm train found car lockout lockout able reset ...  train/vehicle/equipment fault without alarm/fa...  train/vehicle/equipment fault without alarm/fa...
# 1901  Car 73050 CB07 Breaker Found Trip. Please chec...  car breaker found trip please check rectify ch...  train/vehicle/equipment fault with alarms ( re...  train/vehicle/equipment fault with alarms ( re...

# %%
results[results['TARGET']!=results['PREDICTION']].shape[0]
# Out:
# 111

# %%
results[results['TARGET']!=results['PREDICTION']].sample(5)
# Out:
#                                                   NOTES                                    NOTES_PROCESSED                    TARGET                                         PREDICTION
# 108   Time: 0625hrs Loc: WLH Fault: Stn report PD21 ...  time wlh stn report blank vnc verification dis...             display blank                                    default message
# 3266  Date & Time : 171122 / 1056hrs Location : OCC ...  date time occ cc reported dtc gws slow n respo...  gws hang / response slow  train/vehicle/equipment fault with alarms ( re...
# 3957   WLHN @ 2005hrs Fixed Block 419 Out of Service...  wlhn fixed block service imposed track circuit...        track circuit down                     track circuit out of operation
# 643   Time: 2305hrs Loc: FRPS Fault: Track circuit 3...  time frps track circuit operating status servi...        track circuit down                     track circuit out of operation
# 2146   Date & Time: 051022 / 0833hrs  Location:  CNT...  date time cnt station staff reported pd ld dis...             display blank                                     com link error

# %%
# Save file
results.to_csv('results_symptoms.csv')

# %%
# Save
pickle.dump(TFIDF, open('tfidf.pkl', 'wb'))
pickle.dump(rf, open('randomforest_model_symptom.pkl', 'wb'))

# %%
# # Load
# with open('tfidf.pkl', 'rb') as file:
#     vectorizer = pickle.load(file)

# with open('randomforest_model_symptom.pkl', 'rb') as file:
#     model = pickle.load(file)
